# %%
# %run visualizePlotly.py --dataset NELL995
# Out:
# nell > athleteplaysforteam
# Processing file: ./output/NELL995_subgraph/athleteplaysforteam/test_epoch1_75487->398->39829.txt
# Saved visualization to ./visual/NELL995_subgraph/athleteplaysforteam/test_epoch1_75487->398->39829.html
# Processing file: ./output/NELL995_subgraph/athleteplaysforteam/test_epoch3_75475->398->7069.txt
# Saved visualization to ./visual/NELL995_subgraph/athleteplaysforteam/test_epoch3_75475->398->7069.html
# Processing file: ./output/NELL995_subgraph/athleteplaysforteam/test_epoch2_66305->398->17248.txt
# Saved visualization to ./visual/NELL995_subgraph/athleteplaysforteam/test_epoch2_66305->398->17248.html
# Processing file: ./output/NELL995_subgraph/athleteplaysforteam/test_epoch3_75428->398->27285.txt
# Saved visualization to ./visual/NELL995_subgraph/athleteplaysforteam/test_epoch3_75428->398->27285.html
# Processing file: ./output/NELL995_subgraph/athleteplaysforteam/test_epoch2_75438->398->39477.txt
# ...

# %%
# !sh run.sh --dataset WN18RR --test_output_attention --max_attended_nodes 20 --test_max_attended_nodes 20
# Out:
# /opt/anaconda3/envs/tensorFlowGPU1/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Namespace(dataset='WN18RR', n_dims_sm=50, n_dims=100, batch_size=100, max_edges_per_example=10000, max_edges_per_node=200, max_attended_nodes=20, max_seen_nodes=200, test_batch_size=100, test_max_edges_per_example=10000, test_max_edges_per_node=200, test_max_attended_nodes=20, test_max_seen_nodes=200, n_layers=2, aggregate_op='mean_v3', uncon_steps=2, con_steps=8, max_epochs=1, learning_rate=0.001, clipnorm=1.0, remove_all_head_tail_edges=False, timer=False, print_train=True, print_train_metric=True, print_train_freq=1, eval_within_epoch=[], eval_valid=False, moving_mean_decay=0.99, test_output_attention=True, test_analyze_attention=False)
# WN18RR
# ...
